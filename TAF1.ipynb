# %%
from datetime import datetime
import pandas as pd
import numpy as np
import requests

# %%
class Station:
    def __init__(self, nom:str, capteur:int, apiLabel:str) -> None:
        self.nom:str = nom
        self.capteur:int = capteur
        self.apiLabel:str = apiLabel
    
    def obtenirEtat(self):
        url = f"https://data.toulouse-metropole.fr/api/explore/v2.1/catalog/datasets/{self.apiLabel}/records?select=data%2C%20id%2C%20humidite%2C%20pression%2C%20temperature_en_degre_c%2C%20heure_de_paris&order_by=-heure_utc&limit=1"
        response = requests.get(url)
        data = response.json()
        data = pd.DataFrame(data['results']).iloc[0] # première ligne
        record = Record(data["temperature_en_degre_c"], data["humidite"], data["pression"], data["heure_de_paris"], self)
        record.afficher()


class Donnee:
    def __init__(self) -> None:
        pass


class Record:
    def __init__(self, temperature:float, humidite:int, pression:int, heure:datetime, station:Station) -> None:
        self.temperature:float = temperature
        self.humidite:int = humidite
        self.pression:int = pression
        self.heure:datetime = heure
        self.station:Station = station
    
    def afficher(self):
        print(f"{self.heure}\nTempérature : {self.temperature} ; Humidité : {self.humidite} ; Pression : {self.pression}")


class Printing:
    def __init__(self) -> None:
        pass


class DataExtractor:
    def __init__(self) -> None:
        pass


class RecordExtractor:
    @staticmethod
    def extract(data) -> Record:
        temperature = data.get("temperature")
        humidite = data.get("humidite")
        pression = data.get("pression")
        heure = data.get("heure_de_paris")
        station = data.get("id")
        return Record(temperature, humidite, pression, heure, station)
        
        
class CSVExtractor(DataExtractor):
    @staticmethod
    def extract(filename: str):
        return pd.read_csv(filename, sep=";")


class Test:
    def test(line) -> None:
        record = RecordExtractor.extract(line)
        fields = ["temperature", "humidite", "pression", "heure", "station"]
        #passed = True
        for field in fields:
            valeur = getattr(record, field)
            #assert pd.notnull(valeur), f"Le champ {field} est nul dans la ligne extraite!"
            if (not pd.notnull(valeur)):
                #print(f"Le champ {field} est nul dans la ligne!")
                #passed = False
                return False
        #if not passed:
        #    print(f"Test échoué : ligne {i+2}.")
        return True


class TestBatch(Test):
    def test(data):
        for i in range(data.shape[0]):
            if not Test.test(data.iloc[i]):
                print(f"Erreur ligne {i}")


class Clean:
    def __init__(self) -> None:
        pass


class Config:
    def __init__(self) -> None:
        pass


class StationSelector(Config):
    def __init__(self) -> None:
        super().__init__()


# Ajouter la visualisation, le nettoyage(?), le stockage, la transformation, l'extraction, les tests, la config initiale (inputs)
# StationSelector, DataVisualizer

# %%
url = "https://data.toulouse-metropole.fr/api/explore/v2.1/catalog/datasets/42-station-meteo-toulouse-parc-compans-cafarelli/records?select=data%2C%20id%2C%20humidite%2C%20pression%2C%20temperature_en_degre_c%2C%20heure_utc&order_by=-heure_utc&limit=20&offset=0"
response = requests.get(url)
data = response.json()
data = pd.DataFrame(data['results'])
data.head()
# Out:
#                        data  id  humidite  pression  temperature_en_degre_c  \
# 0  5566648fcea850000b801440  42        85     99200                    13.3
# 1  5566646fcea870000ba00040  42        85     99300                    13.3
# 2  5566644fd2a840000ba00040  42        85     99300                    13.4
# 3  5566642fd6a060000ba00040  42        84     99300                    13.5
# 4  5566640fda98d0000ba00080  42        83     99300                    13.6
#
#                    heure_utc
# 0  2025-11-06T08:45:00+00:00
# 1  2025-11-06T08:30:00+00:00
# 2  2025-11-06T08:15:00+00:00
# 3  2025-11-06T08:00:00+00:00
# 4  2025-11-06T07:45:00+00:00

# %%
data.shape
# Out:
# (20, 6)

# %%
data = CSVExtractor.extract("/Users/morrylk/Cours_M1_Ynov/Algo-et-dev/42-station-meteo-toulouse-parc-compans-cafarelli.csv")
data.head()
# Out:
#                        data    id  humidite  direction_du_vecteur_de_vent_max  \
# 0  552a630fca7800000c200000  42.0      79.0                               0.0
# 1  55296af0d61000000c600000  42.0      66.0                               0.0
# 2  55296b509a3800000c600000  42.0      71.0                               0.0
# 3  55296b30a63000000c600000  42.0      70.0                               0.0
# 4  552a63f00e6800000c200800  42.0      77.0                               0.0
#
#    pluie_intensite_max  pression  direction_du_vecteur_vent_moyen  \
# 0                  0.0   99700.0                              0.0
# 1                  0.0   99900.0                              0.0
# 2                  0.0   99900.0                              0.0
# 3                  0.0   99900.0                              0.0
# 4                  0.0   99700.0                              0.0
#
#   type_de_station  pluie  direction_du_vecteur_de_rafale_de_vent_max  \
# ...

# %%
data.isna().sum()
# Out:
# data                                           0
# id                                            19
# humidite                                      20
# direction_du_vecteur_de_vent_max              20
# pluie_intensite_max                           20
# pression                                      20
# direction_du_vecteur_vent_moyen               20
# type_de_station                               20
# pluie                                         20
# direction_du_vecteur_de_rafale_de_vent_max    20
# force_moyenne_du_vecteur_vent                 20
# force_rafale_max                              20
# temperature                                   20
# heure_de_paris                                20
# heure_utc                                     20
# dtype: int64

# %%
data.iloc[0]
# Out:
# data                                           552a630fca7800000c200000
# id                                                                 42.0
# humidite                                                           79.0
# direction_du_vecteur_de_vent_max                                    0.0
# pluie_intensite_max                                                 0.0
# pression                                                        99700.0
# direction_du_vecteur_vent_moyen                                     0.0
# type_de_station                                                     ISS
# pluie                                                               0.0
# direction_du_vecteur_de_rafale_de_vent_max                          0.0
# force_moyenne_du_vecteur_vent                                       0.0
# force_rafale_max                                                    0.0
# temperature                                                        13.2
# ...

# %%
stat1 = Station("Compans Cafarelli", 42, "42-station-meteo-toulouse-parc-compans-cafarelli")
#record1 = Record(data.iloc[0]["temperature_en_degre_c"], data.iloc[0]["humidite"], data.iloc[0]["pression"], data.iloc[0]["heure_utc"], stat1)

# %%
stat1.obtenirEtat()
# Out:
# 2025-11-06T08:45:00+00:00
# Température : 13.3 ; Humidité : 85 ; Pression : 99200

# %%
print(Test.test(data.iloc[55577], 55577))
# Out:
# None

# %%
RecordExtractor.extract(data.iloc[55574]).humidite
# Out:
# np.float64(92.0)

# %%
TestBatch.test(data)
# Out:
# Erreur ligne 5993
# Erreur ligne 18103
# Erreur ligne 18188
# Erreur ligne 20203
# Erreur ligne 20733
# Erreur ligne 27959
# Erreur ligne 28158
# Erreur ligne 28420
# Erreur ligne 49523
# Erreur ligne 50024
# Erreur ligne 55575
# Erreur ligne 55576
# Erreur ligne 55721
# Erreur ligne 62001
# Erreur ligne 62003
# Erreur ligne 73854
# Erreur ligne 73880
# Erreur ligne 80728
# Erreur ligne 94964
# Erreur ligne 135713
