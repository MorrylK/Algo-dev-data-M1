# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.read_csv("/Users/morrylk/Cours_M1_Ynov/Algo-et-dev/42-station-meteo-toulouse-parc-compans-cafarelli.csv", sep=";")
df.head()
# Out:
#                        data    id  humidite  direction_du_vecteur_de_vent_max  \
# 0  552a630fca7800000c200000  42.0      79.0                               0.0
# 1  55296af0d61000000c600000  42.0      66.0                               0.0
# 2  55296b509a3800000c600000  42.0      71.0                               0.0
# 3  55296b30a63000000c600000  42.0      70.0                               0.0
# 4  552a63f00e6800000c200800  42.0      77.0                               0.0
#
#    pluie_intensite_max  pression  direction_du_vecteur_vent_moyen  \
# 0                  0.0   99700.0                              0.0
# 1                  0.0   99900.0                              0.0
# 2                  0.0   99900.0                              0.0
# 3                  0.0   99900.0                              0.0
# 4                  0.0   99700.0                              0.0
#
#   type_de_station  pluie  direction_du_vecteur_de_rafale_de_vent_max  \
# ...

# %%
profile = ProfileReport(df, title="Profiling Report")
profile.to_file("/Users/morrylk/Cours_M1_Ynov/Algo-et-dev/YDATA-meteo.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /opt/anaconda3/lib/python3.13/site-packages/ydata_profiling/model/typeset_relations.py:118: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   return pd.to_datetime(series, format="mixed")
# /opt/anaconda3/lib/python3.13/site-packages/ydata_profiling/model/typeset_relations.py:118: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   return pd.to_datetime(series, format="mixed")
# ...
